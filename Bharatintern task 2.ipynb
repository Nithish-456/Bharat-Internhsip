# %% [markdown]
# # BHARAT INTERN TASK 2 # FLOWERS CLASSIFICATION

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"C:\Users\nithi\Downloads\flowers.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
plt.figure(figsize=(8,6))
plt.title("Correlation Matrix")
sns.heatmap(df.corr(),annot=True,cmap="cool")
plt.show()

# %%
plt.figure(figsize=(7,6))
sns.pairplot(df)

# %%
plt.figure(figsize=(5,4))
plt.title("Species Count")
x=["Setosa","Versicolor","Virginica"]
y=[50,50,50]
plt.barh(x,y,color="coral")
plt.ylabel("Flower Type")
plt.xlabel("Count")
plt.show()

# %%
x=df.drop(['species'],axis=1)
y=df['species']

# %%
from sklearn.model_selection import train_test_split
xtr,xte,ytr,yte=train_test_split(x,y,test_size=0.4,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

# %%
dt=DecisionTreeClassifier(random_state=0)
dt.fit(xtr,ytr)
# Out:
# DecisionTreeClassifier(random_state=0)

# %% [markdown]
# # Feature Importance

# %%
df1=pd.DataFrame({
    "Feature Name": xtr.columns,
    "Importance":dt.feature_importances_
})
f1=df1.sort_values(by="Importance",ascending=False)
f2=f1.head(10)
plt.figure(figsize=(8,6))
sns.barplot(data=f2,x="Importance",y="Feature Name")
plt.title("Features impact on the model")
plt.xlabel('Importance')
plt.ylabel('Feature Name')
plt.show()

# %%
yp1=dt.predict(xte)
yp1
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
# ...

# %%
gb=GaussianNB()
gb.fit(xtr,ytr)
# Out:
# GaussianNB()

# %%
yp2=gb.predict(xte)
yp2
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
# ...

# %%
kn=KNeighborsClassifier(n_neighbors=5,p=2)
kn.fit(xtr,ytr)
# Out:
# KNeighborsClassifier()

# %%
yp3=kn.predict(xte)
yp3
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
# ...

# %%
from sklearn.metrics import accuracy_score,f1_score,confusion_matrix
a=accuracy_score(yte,yp1)
b=f1_score(yte,yp1,average='macro')
print("Accuracy score for Decision Tree:",a*100)
print("F1 Score:",b*100)
# Out:
# Accuracy score for Decision Tree: 95.0
# F1 Score: 95.433316035288

# %%
a=accuracy_score(yte,yp2)
b=f1_score(yte,yp2,average='macro')
print("Accuracy score for Naive Bayes Tree:",a*100)
print("F1 Score:",b*100)
# Out:
# Accuracy score for Naive Bayes Tree: 93.33333333333333
# F1 Score: 93.82456140350878

# %%
a=accuracy_score(yte,yp3)
b=f1_score(yte,yp3,average='macro')
print("Accuracy score for K Neighbors classifier:",a*100)
print("F1 Score:",b*100)
# Out:
# Accuracy score for K Neighbors classifier: 95.0
# F1 Score: 95.433316035288

# %%
x=['Decision Tree','Naive Bayes','K Neighbors classifier']
y=[95.0,93.33,95.0]
data=pd.DataFrame(zip(x,y),columns=["Algorithm","Accuracy"])
data
# Out:
#                 Algorithm  Accuracy
# 0           Decision Tree     95.00
# 1             Naive Bayes     93.33
# 2  K Neighbors classifier     95.00

# %%
x1=['Decision Tree','Naive Bayes','K Neighbors classifier']
y1=[95.433316035288,93.82456140350878,95.433316035288]
data=pd.DataFrame(zip(x1,y1),columns=["Algorithm","F1 Score"])
data
# Out:
#                 Algorithm   F1 Score
# 0           Decision Tree  95.433316
# 1             Naive Bayes  93.824561
# 2  K Neighbors classifier  95.433316

# %%
plt.figure(figsize=(6,5))
plt.title("Accuracy Score chart")
c=['y','g','b']
plt.bar(x,y,color=c)
plt.xlabel("Algorithms")
plt.ylabel("Accuracy")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.title("Accuracy Score chart")
c=['r','b','g']
plt.bar(x1,y1,color=c)
plt.xlabel("Algorithms")
plt.ylabel("F1 Score")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # FINALLY TASK SUCCESSFULLY COMPLETED
